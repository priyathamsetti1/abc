# %% [markdown]
# <a href="https://colab.research.google.com/github/priyathamsetti/abc/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
#loding ds
dataset =pd.read_csv("/content/age_salary_dataset.csv")
#printing ds
dataset
# Out:
#      Age   Salary
# 0   50.0  45056.0
# 1   36.0  72482.0
# 2   29.0  87716.0
# 3   42.0  48110.0
# 4   40.0  53773.0
# ..   ...      ...
# 95  58.0  57675.0
# 96  56.0  92733.0
# 97  43.0  84417.0
# 98  48.0  63938.0
# 99  56.0  63664.0
#
# [100 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# dataset['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# dataset['Salary'].plot(kind='hist', bins=20, title='Salary')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# dataset.plot(kind='scatter', x='Age', y='Salary', s=32, alpha=.8)
# ...

# %%
#extrscting independent var (X) dependent var (Y)
X=dataset.iloc[:,:-1].values
Y=dataset.iloc[:,-1].values
print('independent var(X):',X)
print('dependent var(X):',Y)

# %%
from sklearn.impute import SimpleImputer
# indentifing false value using transformer method
imp = SimpleImputer(missing_values=np.nan,strategy="mean")
X=imp.fit_transform(X)
Y=Y.reshape(-1,1)
Y=imp.fit_transform(Y)
Y=Y.reshape(-1)
print(X)
print(Y)

# %%
# converty X Y to DataFramer
X_df =pd.DataFrame(X,columns=dataset.columns[:-1])
Y_df =pd.DataFrame(Y,columns=[dataset.columns[-1]])
#combine X and Y side by side using pandas.
combine_data =pd.concat([X_df,Y_df], axis=1)
#Display the comine data
print ("combine data :")
print(combine_data)
# Out:
# combine data :
#      Age   Salary
# 0   50.0  45056.0
# 1   36.0  72482.0
# 2   29.0  87716.0
# 3   42.0  48110.0
# 4   40.0  53773.0
# ..   ...      ...
# 95  58.0  57675.0
# 96  56.0  92733.0
# 97  43.0  84417.0
# 98  48.0  63938.0
# 99  56.0  63664.0
#
# [100 rows x 2 columns]

# %%
#combine ds
combine_df =pd.DataFrame(combine_data,columns=list(dataset.columns))
#save
combine_df.to_excel("/content/combine_data.xlsx",index=False)
#DISPLAY
print("combine DataFrame:")
print(combine_df.head())
# Out:
# combine DataFrame:
#     Age   Salary
# 0  50.0  45056.0
# 1  36.0  72482.0
# 2  29.0  87716.0
# 3  42.0  48110.0
# 4  40.0  53773.0
